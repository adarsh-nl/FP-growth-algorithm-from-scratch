# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools

# %%
DEBUG = False

def debug(str):
  if DEBUG:
    print(str)

# %%
def load_data(data_path):
  Transactions = []
  
  with open (data_path, 'r') as data:
    for lines in data:
      str_line = list(lines.strip().split(','))
      Transactions.append(str_line)
  return Transactions

# %%
path = "/content/data.txt"
transactions = load_data(path)
#transactions.remove('')

# %%
print(transactions[:100])
# Out:
# [['Lassi', 'Coffee Powder', 'Butter', 'Yougurt', 'Ghee', 'Cheese', ''], ['Ghee', 'Coffee Powder', ''], ['Lassi', 'Tea Powder', 'Butter', 'Cheese', ''], ['Cheese', 'Tea Powder', 'Panner', 'Coffee Powder', 'Butter', 'Bread', ''], ['Cheese', 'Yougurt', 'Coffee Powder', 'Sugar', 'Butter', 'Sweet', ''], ['Sugar', 'Tea Powder', 'Ghee', 'Sweet', 'Panner', 'Milk', ''], ['Sweet', 'Coffee Powder', ''], ['Butter', 'Ghee', 'Panner', ''], ['Sweet', 'Tea Powder', 'Butter', 'Yougurt', 'Sugar', 'Cheese', ''], ['Panner', 'Ghee', ''], ['Milk', 'Panner', 'Tea Powder', 'Sweet', 'Bread', ''], ['Ghee', 'Coffee Powder', 'Milk', 'Yougurt', 'Lassi', 'Sugar', 'Butter', 'Panner', ''], ['Butter', 'Coffee Powder', 'Panner', 'Sweet', 'Ghee', 'Lassi', ''], ['Bread', 'Lassi', 'Coffee Powder', 'Tea Powder', 'Sweet', 'Ghee', 'Sugar', 'Panner', ''], ['Milk', 'Sweet', 'Butter', 'Sugar', 'Lassi', 'Panner', ''], ['Bread', 'Coffee Powder', 'Tea Powder', ''], ['Butter', 'Ghee', 'Milk', 'Cheese', ''], ['Bread', 'Coffee Powder', ''], ['Cheese', 'Tea Powder', 'Sweet', 'Lassi', 'Coffee Powder', 'Sugar', ''], ['Panner', 'Lassi', 'Butter', 'Cheese', 'Yougurt', 'Tea Powder', 'Milk', ''], ['Coffee Powder', 'Cheese', 'Tea Powder', 'Yougurt', 'Sugar', ''], ['Lassi', 'Ghee', 'Cheese', 'Sweet', 'Coffee Powder', 'Bread', ''], ['Coffee Powder', 'Panner', 'Butter', 'Ghee', 'Tea Powder', 'Yougurt', ''], ['Yougurt', 'Sweet', 'Milk', 'Butter', 'Coffee Powder', 'Lassi', ''], ['Sugar', 'Coffee Powder', 'Milk', 'Butter', 'Cheese', 'Yougurt', ''], ['Lassi', 'Yougurt', 'Ghee', 'Cheese', 'Butter', 'Milk', 'Panner', ''], ['Panner', 'Yougurt', 'Sugar', 'Coffee Powder', 'Milk', 'Cheese', ''], ['Panner', 'Milk', 'Sweet', ''], ['Bread', 'Coffee Powder', ''], ['Sweet', 'Cheese', ''], ['Yougurt', 'Bread', 'Tea Powder', 'Coffee Powder', ''], ['Lassi', 'Sweet', 'Panner', ''], ['Milk', 'Butter', 'Bread', 'Tea Powder', 'Panner', 'Ghee', ''], ['Butter', 'Cheese', 'Panner', 'Sugar', ''], ['Cheese', 'Yougurt', 'Sugar', 'Bread', 'Butter', 'Panner', ''], ['Lassi', 'Bread', 'Panner', 'Milk', ''], ['Ghee', 'Bread', 'Cheese', 'Sugar', 'Coffee Powder', 'Sweet', 'Yougurt', 'Lassi', ''], ['Bread', 'Yougurt', 'Ghee', 'Tea Powder', 'Panner', 'Milk', 'Lassi', 'Coffee Powder', ''], ['Sugar', 'Milk', 'Butter', 'Ghee', 'Cheese', ''], ['Cheese', 'Panner', 'Sugar', 'Yougurt', 'Ghee', ''], ['Sweet', 'Panner', 'Bread', ''], ['Coffee Powder', 'Milk', 'Bread', ''], ['Cheese', 'Lassi', 'Coffee Powder', 'Tea Powder', 'Bread', 'Panner', 'Butter', ''], ['Cheese', 'Tea Powder', 'Milk', 'Yougurt', 'Ghee', ''], ['Sugar', 'Yougurt', 'Bread', 'Butter', 'Ghee', 'Milk', 'Lassi', ''], ['Butter', 'Tea Powder', 'Cheese', 'Yougurt', 'Bread', 'Ghee', 'Coffee Powder', ''], ['Sugar', 'Milk', ''], ['Sweet', 'Butter', ''], ['Yougurt', 'Bread', 'Sweet', ''], ['Cheese', 'Coffee Powder', 'Butter', 'Sugar', 'Panner', 'Bread', 'Lassi', 'Tea Powder', 'Ghee', ''], ['Yougurt', 'Panner', 'Butter', 'Lassi', 'Sugar', 'Bread', 'Tea Powder', 'Milk', ''], ['Butter', 'Lassi', ''], ['Sugar', 'Panner', 'Tea Powder', 'Sweet', 'Coffee Powder', 'Cheese', 'Lassi', 'Milk', 'Butter', ''], ['Lassi', 'Butter', ''], ['Coffee Powder', 'Butter', 'Ghee', ''], ['Lassi', 'Butter', 'Bread', 'Ghee', 'Coffee Powder', ''], ['Butter', 'Sugar', 'Yougurt', ''], ['Lassi', 'Butter', ''], ['Ghee', 'Bread', 'Cheese', 'Lassi', 'Tea Powder', 'Coffee Powder', 'Sweet', 'Butter', ''], ['Panner', 'Milk', 'Bread', 'Yougurt', ''], ['Panner', 'Tea Powder', ''], ['Bread', 'Panner', ''], ['Yougurt', 'Sugar', 'Sweet', 'Ghee', 'Bread', 'Butter', 'Coffee Powder', 'Lassi', 'Tea Powder', 'Milk', 'Panner', ''], ['Tea Powder', 'Sweet', 'Lassi', 'Ghee', ''], ['Lassi', 'Coffee Powder', 'Sugar', ''], ['Cheese', 'Sugar', 'Tea Powder', 'Butter', ''], ['Bread', 'Yougurt', 'Milk', 'Panner', 'Sweet', 'Tea Powder', 'Cheese', ''], ['Bread', 'Ghee', 'Yougurt', 'Milk', 'Coffee Powder', ''], ['Coffee Powder', 'Butter', 'Lassi', 'Ghee', ''], ['Lassi', 'Bread', 'Coffee Powder', 'Milk', 'Sugar', ''], ['Ghee', 'Milk', ...

# %%
def find_uniItems(transactions):
  unique_items = []
  for i in transactions:
    for j in i:
      if j not in unique_items:
        unique_items.append(j)
  return unique_items

# %%
unique_items = find_uniItems(transactions)
unique_items.remove('')
print("Unique_items in the transactional data are:\n{}".format(unique_items))
# Out:
# Unique_items in the transactional data are:
# ['Lassi', 'Coffee Powder', 'Butter', 'Yougurt', 'Ghee', 'Cheese', 'Tea Powder', 'Panner', 'Bread', 'Sugar', 'Sweet', 'Milk']

# %%
from collections import Counter

def find_frequency(lists):
    result = {}
    for sub_list in lists:
        sub_list_counter = Counter(sub_list)
        for item, count in sub_list_counter.items():
            if item in result:
                result[item] += count
            else:
                result[item] = count
    return result

# %%
frequent_item_sets = find_frequency(transactions)
print(frequent_item_sets)
# Out:
# {'Lassi': 5432, 'Coffee Powder': 5509, 'Butter': 5481, 'Yougurt': 5503, 'Ghee': 5510, 'Cheese': 5476, '': 12527, 'Tea Powder': 5383, 'Panner': 5444, 'Bread': 5484, 'Sugar': 5482, 'Sweet': 5483, 'Milk': 5526}

# %%
min_support = (40/100)*len(transactions) #current min support is 40%
print("The minimum support of the dataset is: {}".format(min_support))
# Out:
# The minimum support of the dataset is: 5010.8

# %%
def remove_infrequent_and_sort(frequent_item_sets, min_support):
  temp_itemset = frequent_item_sets.copy()
  for key,values in frequent_item_sets.items():
    if values < min_support:
      temp_itemset.pop(key)
    elif key == '':
      temp_itemset.pop(key)
    else:
      continue
      
  frequent_item_sets = temp_itemset
  keys = list(frequent_item_sets.keys())
  values = list(frequent_item_sets.values())
  sorted_value_index = np.argsort(values)
  sorted_value_index = np.flip(sorted_value_index)
  frequent_item_sets = {keys[i]: values[i] for i in sorted_value_index}
  return frequent_item_sets

frequent_item_sets = remove_infrequent_and_sort(frequent_item_sets, min_support)
print("The frequent item sets that satisfy the support count are: {}".format(frequent_item_sets))
# Out:
# The frequent item sets that satisfy the support count are: {'Milk': 5526, 'Ghee': 5510, 'Coffee Powder': 5509, 'Yougurt': 5503, 'Bread': 5484, 'Sweet': 5483, 'Sugar': 5482, 'Butter': 5481, 'Cheese': 5476, 'Panner': 5444, 'Lassi': 5432, 'Tea Powder': 5383}

# %%
def build_ordered_itemset(transactions, frequent_item_sets):
    keys = list(frequent_item_sets.keys())
    temp_transactions = []
    for transaction in transactions:
        temp_items = []
        for item in transaction:
            if item in keys:
                temp_items.append(item)
        temp_transactions.append(temp_items)
    
    transactions = []
    for temp_transaction in temp_transactions:
        new_transaction = []
        for key in keys:
            if key in temp_transaction:
                new_transaction.append(key)
        transactions.append(new_transaction)
    
    return transactions

transactions = build_ordered_itemset(transactions, frequent_item_sets)
print(transactions)
# Out:
# [['Ghee', 'Coffee Powder', 'Yougurt', 'Butter', 'Cheese', 'Lassi'], ['Ghee', 'Coffee Powder'], ['Butter', 'Cheese', 'Lassi', 'Tea Powder'], ['Coffee Powder', 'Bread', 'Butter', 'Cheese', 'Panner', 'Tea Powder'], ['Coffee Powder', 'Yougurt', 'Sweet', 'Sugar', 'Butter', 'Cheese'], ['Milk', 'Ghee', 'Sweet', 'Sugar', 'Panner', 'Tea Powder'], ['Coffee Powder', 'Sweet'], ['Ghee', 'Butter', 'Panner'], ['Yougurt', 'Sweet', 'Sugar', 'Butter', 'Cheese', 'Tea Powder'], ['Ghee', 'Panner'], ['Milk', 'Bread', 'Sweet', 'Panner', 'Tea Powder'], ['Milk', 'Ghee', 'Coffee Powder', 'Yougurt', 'Sugar', 'Butter', 'Panner', 'Lassi'], ['Ghee', 'Coffee Powder', 'Sweet', 'Butter', 'Panner', 'Lassi'], ['Ghee', 'Coffee Powder', 'Bread', 'Sweet', 'Sugar', 'Panner', 'Lassi', 'Tea Powder'], ['Milk', 'Sweet', 'Sugar', 'Butter', 'Panner', 'Lassi'], ['Coffee Powder', 'Bread', 'Tea Powder'], ['Milk', 'Ghee', 'Butter', 'Cheese'], ['Coffee Powder', 'Bread'], ['Coffee Powder', 'Sweet', 'Sugar', 'Cheese', 'Lassi', 'Tea Powder'], ['Milk', 'Yougurt', 'Butter', 'Cheese', 'Panner', 'Lassi', 'Tea Powder'], ['Coffee Powder', 'Yougurt', 'Sugar', 'Cheese', 'Tea Powder'], ['Ghee', 'Coffee Powder', 'Bread', 'Sweet', 'Cheese', 'Lassi'], ['Ghee', 'Coffee Powder', 'Yougurt', 'Butter', 'Panner', 'Tea Powder'], ['Milk', 'Coffee Powder', 'Yougurt', 'Sweet', 'Butter', 'Lassi'], ['Milk', 'Coffee Powder', 'Yougurt', 'Sugar', 'Butter', 'Cheese'], ['Milk', 'Ghee', 'Yougurt', 'Butter', 'Cheese', 'Panner', 'Lassi'], ['Milk', 'Coffee Powder', 'Yougurt', 'Sugar', 'Cheese', 'Panner'], ['Milk', 'Sweet', 'Panner'], ['Coffee Powder', 'Bread'], ['Sweet', 'Cheese'], ['Coffee Powder', 'Yougurt', 'Bread', 'Tea Powder'], ['Sweet', 'Panner', 'Lassi'], ['Milk', 'Ghee', 'Bread', 'Butter', 'Panner', 'Tea Powder'], ['Sugar', 'Butter', 'Cheese', 'Panner'], ['Yougurt', 'Bread', 'Sugar', 'Butter', 'Cheese', 'Panner'], ['Milk', 'Bread', 'Panner', 'Lassi'], ['Ghee', 'Coffee Powder', 'Yougurt', 'Bread', 'Sweet', 'Sugar', 'Cheese', 'Lassi'], ['Milk', 'Ghee', 'Coffee Powder', 'Yougurt', 'Bread', 'Panner', 'Lassi', 'Tea Powder'], ['Milk', 'Ghee', 'Sugar', 'Butter', 'Cheese'], ['Ghee', 'Yougurt', 'Sugar', 'Cheese', 'Panner'], ['Bread', 'Sweet', 'Panner'], ['Milk', 'Coffee Powder', 'Bread'], ['Coffee Powder', 'Bread', 'Butter', 'Cheese', 'Panner', 'Lassi', 'Tea Powder'], ['Milk', 'Ghee', 'Yougurt', 'Cheese', 'Tea Powder'], ['Milk', 'Ghee', 'Yougurt', 'Bread', 'Sugar', 'Butter', 'Lassi'], ['Ghee', 'Coffee Powder', 'Yougurt', 'Bread', 'Butter', 'Cheese', 'Tea Powder'], ['Milk', 'Sugar'], ['Sweet', 'Butter'], ['Yougurt', 'Bread', 'Sweet'], ['Ghee', 'Coffee Powder', 'Bread', 'Sugar', 'Butter', 'Cheese', 'Panner', 'Lassi', 'Tea Powder'], ['Milk', 'Yougurt', 'Bread', 'Sugar', 'Butter', 'Panner', 'Lassi', 'Tea Powder'], ['Butter', 'Lassi'], ['Milk', 'Coffee Powder', 'Sweet', 'Sugar', 'Butter', 'Cheese', 'Panner', 'Lassi', 'Tea Powder'], ['Butter', 'Lassi'], ['Ghee', 'Coffee Powder', 'Butter'], ['Ghee', 'Coffee Powder', 'Bread', 'Butter', 'Lassi'], ['Yougurt', 'Sugar', 'Butter'], ['Butter', 'Lassi'], ['Ghee', 'Coffee Powder', 'Bread', 'Sweet', 'Butter', 'Cheese', 'Lassi', 'Tea Powder'], ['Milk', 'Yougurt', 'Bread', 'Panner'], ['Panner', 'Tea Powder'], ['Bread', 'Panner'], ['Milk', 'Ghee', 'Coffee Powder', 'Yougurt', 'Bread', 'Sweet', 'Sugar', 'Butter', 'Panner', 'Lassi', 'Tea Powder'], ['Ghee', 'Sweet', 'Lassi', 'Tea Powder'], ['Coffee Powder', 'Sugar', 'Lassi'], ['Sugar', 'Butter', 'Cheese', 'Tea Powder'], ['Milk', 'Yougurt', 'Bread', 'Sweet', 'Cheese', 'Panner', 'Tea Powder'], ['Milk', 'Ghee', 'Coffee Powder', 'Yougurt', 'Bread'], ['Ghee', 'Coffee Powder', 'Butter', 'Lassi'], ['Milk', 'Coffee Powder', 'Bread', 'Sugar', 'Lassi'], ['Milk', 'Ghee', 'Coffee Powder', 'Yougurt', 'Sweet'], ['Milk', 'Ghee', 'Coffee Powder', 'Sweet', 'Sugar', 'Panner', 'Tea Powder'], ['Milk', 'Bread', 'Panner', 'Lassi', 'Tea Powder'], ['Ghee', 'Yougurt', 'Bread', 'Sweet', 'Sugar', 'Butter', 'Tea Powder'], ['Coffee Powder', 'Panner', 'Tea Powder' ...

# %%
class Node:
    def __init__(self, item, count, parent):
        self.item = item
        self.count = count
        self.parent = parent
        self.children = {}
        self.next_node = None
        self.link = None

    def add_child(self, child):
        if child.item not in self.children:
            self.children[child.item] = child

    def increment_count(self, count):
        self.count += count

    def get_nodes_with_item(self, item):
        nodes = []
        if self.item == item:
            nodes.append(self)
        for child in self.children.values():
            nodes.extend(child.get_nodes_with_item(item))
        return nodes

class FPTree:
    def __init__(self):
        self.root = Node("*", 0, None)
        self.header_table = {}

    def add_transaction(self, transaction):
        current_node = self.root
        for item in transaction:
            child_node = current_node.children.get(item)
            if child_node is None:
                child_node = Node(item, 0, current_node)
                current_node.children[item] = child_node
                if item in self.header_table:
                    last_node = self.header_table[item]
                    while last_node.link is not None:
                        last_node = last_node.link
                    last_node.link = child_node
                else:
                    self.header_table[item] = child_node
            child_node.increment_count(1)
            current_node = child_node

    def get_frequent_items(self, min_support):
        frequent_items = {}
        for item in self.header_table:
            support = 0
            node = self.header_table[item]
            while node is not None:
                support += node.count
                node = node.link
            if support >= min_support:
                frequent_items[item] = support
        return frequent_items
    
    def get_nodes_with_item(self, item):
        return self.header_table.get(item, [])

# %%
def find_pattern_base(fptree, node, item):
    pattern_base = {}
    while node is not None:
        prefix_path = []
        temp_node = node
        while temp_node.parent is not None:
            if temp_node.name != "null" and temp_node.name != item:
                prefix_path.append(temp_node.name)
            temp_node = temp_node.parent
        if len(prefix_path) > 0:
            pattern_base[frozenset(prefix_path)] = node.count
        if node.link is None:
            break
        node = node.link
    return pattern_base

def create_subtree(fptree, min_support):
    items = list(fptree.header_table.keys())
    for item in items:
        support = 0
        node = fptree.header_table[item]
        while node is not None:
            support += node.count
            node = node.link
        if support < min_support:
            del fptree.header_table[item]
        else:
            fptree.header_table[item] = support
    for item in fptree.header_table:
        nodes = []
        node = fptree.header_table[item]
        while node is not None:
            nodes.append(node)
            node = node.link
        fptree.header_table[item] = nodes
    conditional_tree = FPTree()
    for item in items:
        pattern_base = find_pattern_base(fptree.root, item)
        for transaction, count in pattern_base.items():
            transaction_list = list(transaction)
            for i in range(count):
                conditional_tree.add_transaction(transaction_list)
    frequent_items = conditional_tree.get_frequent_items(min_support)
    for item in frequent_items:
        conditional_tree.header_table[item] = frequent_items[item]
    return conditional_tree

def generate_frequent_patterns(fptree, min_support, prefix=[]):
    items = [v[0] for v in sorted(fptree.items(), key=lambda kv: kv[1]['support'])]
    for item in items:
        new_prefix = prefix.copy()
        new_prefix.append(item)
        support = fptree[item]["support"]
        yield (new_prefix, support)
        conditional_pattern_base = find_pattern_base(fptree[item]["node_link"], item)
        conditional_tree = create_subtree(conditional_pattern_base, min_support)
        if len(conditional_tree) > 0:
            for pattern in generate_frequent_patterns(conditional_tree, min_support, new_prefix):
                yield pattern

# %%
class FP_Growth:
    def __init__(self, transactions, min_support):
        self.transactions = transactions
        self.min_support = min_support

    def build_fptree(self):
        self.fptree = FPTree()
        for transaction in self.transactions:
            self.fptree.add_transaction(transaction)

    def generate_frequent_itemsets(self, node, suffix):
        frequent_itemsets = []
        support = node.count
        for item, child_node in node.children.items():
            itemset = suffix.copy()
            itemset.add(item)
            frequent_itemsets.append((itemset, support))
            frequent_itemsets.extend(self.generate_frequent_itemsets(child_node, itemset))
        return frequent_itemsets

    def mine_frequent_itemsets(self):
        self.build_fptree()
        frequent_itemsets = []
        for item, count in self.fptree.get_frequent_items(self.min_support).items():
            frequent_itemsets.append((frozenset([item]), count))
        for itemset in itertools.chain.from_iterable(
                self.generate_frequent_itemsets(self.fptree.header_table[item], set()) for item in self.fptree.header_table):
            frequent_itemsets.append(itemset)
        return frequent_itemsets

# %%
fp = FP_Growth(transactions, min_support)
frequent_itemsets = fp.mine_frequent_itemsets()

# %%
print(frequent_itemsets)
# Out:
# [(frozenset({'Ghee'}), 5510), (frozenset({'Coffee Powder'}), 5509), (frozenset({'Yougurt'}), 5503), (frozenset({'Butter'}), 5481), (frozenset({'Cheese'}), 5476), (frozenset({'Lassi'}), 5432), (frozenset({'Tea Powder'}), 5383), (frozenset({'Bread'}), 5484), (frozenset({'Panner'}), 5444), (frozenset({'Sweet'}), 5483), (frozenset({'Sugar'}), 5482), (frozenset({'Milk'}), 5526), ({'Coffee Powder'}, 2999), ({'Yougurt', 'Coffee Powder'}, 1381), ({'Yougurt', 'Butter', 'Coffee Powder'}, 629), ({'Yougurt', 'Butter', 'Cheese', 'Coffee Powder'}, 57), ({'Yougurt', 'Butter', 'Lassi', 'Coffee Powder', 'Cheese'}, 21), ({'Yougurt', 'Butter', 'Cheese', 'Lassi', 'Coffee Powder', 'Tea Powder'}, 7), ({'Yougurt', 'Butter', 'Coffee Powder', 'Tea Powder', 'Cheese'}, 21), ({'Yougurt', 'Butter', 'Panner', 'Coffee Powder', 'Cheese'}, 21), ({'Yougurt', 'Butter', 'Panner', 'Cheese', 'Lassi', 'Coffee Powder'}, 7), ({'Yougurt', 'Butter', 'Panner', 'Cheese', 'Lassi', 'Coffee Powder', 'Tea Powder'}, 4), ({'Yougurt', 'Butter', 'Panner', 'Cheese', 'Coffee Powder', 'Tea Powder'}, 7), ({'Yougurt', 'Butter', 'Panner', 'Coffee Powder'}, 57), ({'Yougurt', 'Butter', 'Panner', 'Coffee Powder', 'Tea Powder'}, 19), ({'Yougurt', 'Butter', 'Panner', 'Lassi', 'Coffee Powder'}, 19), ({'Yougurt', 'Butter', 'Panner', 'Lassi', 'Coffee Powder', 'Tea Powder'}, 10), ({'Yougurt', 'Butter', 'Lassi', 'Coffee Powder'}, 57), ({'Yougurt', 'Butter', 'Lassi', 'Coffee Powder', 'Tea Powder'}, 7), ({'Yougurt', 'Butter', 'Coffee Powder', 'Tea Powder'}, 57), ({'Yougurt', 'Bread', 'Coffee Powder'}, 629), ({'Yougurt', 'Bread', 'Sweet', 'Coffee Powder'}, 303), ({'Yougurt', 'Sweet', 'Coffee Powder', 'Bread', 'Sugar'}, 140), ({'Yougurt', 'Coffee Powder', 'Cheese', 'Bread', 'Sugar', 'Sweet'}, 64), ({'Yougurt', 'Coffee Powder', 'Cheese', 'Bread', 'Sugar', 'Lassi', 'Sweet'}, 18), ({'Yougurt', 'Coffee Powder', 'Cheese', 'Bread', 'Sugar', 'Lassi', 'Sweet', 'Tea Powder'}, 3), ({'Yougurt', 'Coffee Powder', 'Panner', 'Cheese', 'Bread', 'Sugar', 'Sweet'}, 18), ({'Yougurt', 'Coffee Powder', 'Panner', 'Cheese', 'Bread', 'Sugar', 'Lassi', 'Sweet'}, 10), ({'Yougurt', 'Panner', 'Lassi', 'Coffee Powder', 'Sweet', 'Tea Powder', 'Cheese', 'Bread', 'Sugar'}, 5), ({'Yougurt', 'Coffee Powder', 'Panner', 'Cheese', 'Bread', 'Sugar', 'Sweet', 'Tea Powder'}, 10), ({'Yougurt', 'Coffee Powder', 'Cheese', 'Bread', 'Sugar', 'Sweet', 'Tea Powder'}, 18), ({'Yougurt', 'Butter', 'Coffee Powder', 'Bread', 'Sugar', 'Sweet'}, 64), ({'Yougurt', 'Butter', 'Coffee Powder', 'Bread', 'Sugar', 'Sweet', 'Tea Powder'}, 28), ({'Yougurt', 'Butter', 'Coffee Powder', 'Bread', 'Sugar', 'Lassi', 'Sweet'}, 28), ({'Yougurt', 'Butter', 'Coffee Powder', 'Bread', 'Sugar', 'Lassi', 'Sweet', 'Tea Powder'}, 2), ({'Yougurt', 'Butter', 'Coffee Powder', 'Panner', 'Bread', 'Sugar', 'Sweet'}, 28), ({'Yougurt', 'Butter', 'Coffee Powder', 'Panner', 'Bread', 'Sugar', 'Lassi', 'Sweet'}, 12), ({'Yougurt', 'Butter', 'Panner', 'Lassi', 'Coffee Powder', 'Sweet', 'Tea Powder', 'Bread', 'Sugar'}, 7), ({'Yougurt', 'Butter', 'Coffee Powder', 'Panner', 'Bread', 'Sugar', 'Sweet', 'Tea Powder'}, 12), ({'Yougurt', 'Butter', 'Coffee Powder', 'Cheese', 'Bread', 'Sugar', 'Sweet'}, 28), ({'Yougurt', 'Butter', 'Coffee Powder', 'Cheese', 'Bread', 'Sugar', 'Lassi', 'Sweet'}, 6), ({'Yougurt', 'Butter', 'Coffee Powder', 'Panner', 'Cheese', 'Bread', 'Sugar', 'Sweet'}, 6), ({'Yougurt', 'Butter', 'Panner', 'Coffee Powder', 'Sweet', 'Tea Powder', 'Cheese', 'Bread', 'Sugar'}, 4), ({'Yougurt', 'Coffee Powder', 'Bread', 'Sugar', 'Lassi', 'Sweet'}, 64), ({'Yougurt', 'Coffee Powder', 'Bread', 'Sugar', 'Lassi', 'Sweet', 'Tea Powder'}, 4), ({'Yougurt', 'Coffee Powder', 'Panner', 'Bread', 'Sugar', 'Sweet'}, 64), ({'Yougurt', 'Coffee Powder', 'Panner', 'Bread', 'Sugar', 'Sweet', 'Tea Powder'}, 9), ({'Yougurt', 'Coffee Powder', 'Panner', 'Bread', 'Sugar', 'Lassi', 'Sweet'}, 9), ({'Yougurt', 'Coffee Powder', 'Panner', 'Bread', 'Sugar', 'Lassi', 'Sweet', 'Tea Powder'}, 2), ({'Yougurt', 'Sweet', 'Co ...
